# %%
from  import preporcess
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-5-62a8bbe13381> in <module>()
# ----> 1 from . import preporcess
#
# SystemError: Parent module '' not loaded, cannot perform relative import

# %%
import pandas as pd

# %%
df = pd.read_csv('画像部分字段说明.csv')

# %%
df
# Out:
#         模型编号        分类编号      分类名称  \
# 0   RB002001  RB00200105       低贡献
# 1   RB002004  RB00200404   手机银行偏好型
# 2   RB002002  RB00200202     资产均衡型
# 3   RB002001  RB00200101       高贡献
# 4   RB002002  RB00200201     理财偏好型
# 5   RB002004  RB00200401     柜台偏好型
# 6   RB002003  RB00200301       高活跃
# 7   RB002004  RB00200402   自助设备偏好型
# 8   RB002003  RB00200302      较高活跃
# 9   RB002003  RB00200304       低活跃
# 10  RB002001  RB00200103       中贡献
# 11  RB002002  RB00200206     贷款偏好型
# 12  RB002004  RB00200403     渠道均衡型
# 13  RB002004  RB00200406  POS交易偏好型
# 14  RB002003  RB00200303       中活跃
# 15  RB002001  RB00200104      较低贡献
# 16  RB002004  RB00200405     网银偏好型
# 17  RB002002  RB00200204     活储偏好型
# 18  RB002001  RB00200102      较高贡献
# 19  RB002002  RB00200205     定存偏好型
# 20  RB002002  RB00200203     基债偏好型
#
#                                                  分类说明       生效日期       开始日期  \
# 0   客户历史累计积分排名前80%到60%，且近三个月新增积分排名后20%；或者客户历史累计积分排...  2015/3/31  2015/5/26
# ...

# %%
for name in df.ix[:,['分类名称' ,'分类说明']].values:
    print('>>>{0}<<<'.format(name[0]))
    print(name[1])
    print()
# Out:
# >>>低贡献<<<
# 客户历史累计积分排名前80%到60%，且近三个月新增积分排名后20%；或者客户历史累计积分排名后20%，且近三个月新增积分排名后40%；该类客户约占22%。
#
# >>>手机银行偏好型<<<
# 手机银行交易次数与金额占比是手机银行平均水平的2倍以上；自助设备，网银，柜台，POS交易等渠道交易次数与金额占比是各渠道平均水平以下。该类客户约占11.79%，具有年龄小，账龄短，金融资产较高，交易活跃，男性客户占比高等特征。
#
# >>>资产均衡型<<<
# 客户存款，理财，基金，国债，保险，贵金属，私人撮合委托贷款，三方存管等资产均较高，基本各项资产排名在所有六类客户群中的第2名，八项总资产最高，超过平均总资产近2倍。该类客户约占14.66%，具有年龄长，账龄长，金融资产高，产品持有个数多等特征。
#
# >>>高贡献<<<
# 客户历史累计积分排名前20%，且近三个月新增积分排名前40%；或者是客户历史累计积分排名在前40%到20%之间，且近三个月新增积分排名在前20%；该类客户约占22%。
#
# >>>理财偏好型<<<
# 客户理财资产占比高，是平均理财占比的近2倍；高于其他各客户群的理财占比。且存款，基金，国债，保险，贵金属，私人撮合委托贷款，三方存管资产均低于平均水平；该类客户约占12.85%，具有账龄长，金融资产高，女性占比高，产品持有个数多，但交易不够活跃，偏好网银渠道等特征。
#
# >>>柜台偏好型<<<
# 柜台交易次数与金额占比是柜台平均水平的五倍以上；自助设备，网银，手机银行，POS交易等渠道交易次数与金额占比是各渠道平均水平10%以下。该类客户约占17.06%，具有年龄大，账龄长，女性占比高，金融资产较高，定存占比高，交易不活跃，持有产品个数少等特征。
#
# >>>高活跃<<<
# 高活跃群的平均交易次数与平均交易金额相对最高；高活跃群的平均交易次数是平均水平2倍以上；高活跃群的平均交易金额是平均水平2倍以上；该类客户约占33.50%，具有年龄小，账龄短，持有产品数多，金融资产高等特征。
#
# >>>自助设备偏好型<<<
# ...
